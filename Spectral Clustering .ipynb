# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:, 3:5].values
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import SpectralClustering
sc = SpectralClustering(n_clusters=8, assign_labels='discretize', affinity='precomputed', n_init=10, random_state=5)
y_sc = sc.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.cluster import SpectralClustering
#       2 sc = SpectralClustering(n_clusters=8, assign_labels='discretize', affinity='precomputed', n_init=10, random_state=5)
# ----> 3 y_sc = sc.fit_predict(X)
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/sklearn/cluster/_spectral.py:796, in SpectralClustering.fit_predict(self, X, y)
#     774 def fit_predict(self, X, y=None):
#     775     """Perform spectral clustering on `X` and return cluster labels.
#     776
#     777     Parameters
#    (...)    794         Cluster labels.
#     795     """
# --> 796     return super().fit_predict(X, y)
#
# File /opt/anaconda3/envs/aiml/lib/python3.13/site-packages/sklearn/base.py:695, in ClusterMixin.fit_predict(self, X, y, **kwargs)
#     672 """
# ...

# %%
sc

# %%
sc.labels_

# %%
supervised=pd.DataFrame(dataset)
supervised['Cluster_group']=sc.labels_
supervised

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, facet_kws={"legend_out": True})
